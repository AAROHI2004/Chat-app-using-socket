# %% [markdown]
# <a href="https://colab.research.google.com/github/AAROHI2004/Chat-app-using-socket/blob/main/chat.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import json
import string
import random
import nltk
import numpy as num
from nltk.stem import WordNetLemmatizer
import tensorflow as tensorF
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense, Dropout
nltk.download("punkt")
nltk.download("wordnet")
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# True

# %%
ourData = {"ourIntents": [

             {"tag": "age",
              "patterns": ["how old are you?"],
              "responses": ["I am 2 years old and my birthday was yesterday"]
             },
             {"tag": "ORN Visibility Issue",
              "patterns": ["How can I troubleshoot if ORN is not visible in POS due to no data found?", "ORN not visible in POS, what to do?" ],
              "responses": ["If the Work Order (WO) has not been processed in JPW, the ORN will not be visible in POS. The ORN will only appear in POS once JPW initiates the Collect Payment process. Ensure that pre-payment tasks are completed in JPW before processing the POS journey."]
             },
             {
        "tag": "Payment Link Issues",
        "patterns": [
            "What steps should be taken if the payment link fails to open on the customer's mobile?",
            "How do I ensure payment confirmation reflects in JPW after a successful online payment via link in POS?"
        ],
        "responses": [
            "To resolve this, ensure the customer's browser is updated, and they have a stable internet connection. If the customer faces slow internet or no access, the engineer may need to provide hotspot support. Additionally, if the customer keeps the browser open for an extended period, a time-out issue may occur.",
            "For all payment collections in POS, after the customer completes the payment online via the provided link, you need to select the 'payment via link' option. This includes credit card, debit card, net banking, UPI, and various wallets like PayTM and JIOMoney. Avoid choosing the EZEtap card or PayTM option available in POS for collecting payment from the customer."
        ]
    },
             {
        "tag": "Payment Confirmation in JPW",
        "patterns": [
            "What steps should I follow to make sure payment confirmation reflects in JPW after processing a payment via link in POS?"
        ],
        "responses": [
            "In POS, after sending the payment link to the customer, the engineer needs to click on the check-out option, confirm in POS that the payment was done via the link, and then log in again to JPW for the update to reflect."
        ]
    },
             {
        "tag": "POS Errors and Resolutions",
        "patterns": [
            "How do I resolve an error in POS during payment initiation due to the engineer being mapped in an adjacent JC?"
        ],
        "responses": [
            "To resolve this, the engineer needs to go to the Burger menu, select Utility, and perform an 'unregister devices' action. This process only needs to be done once. Afterward, the engineer can collect money from the mapped JC without any issues."
        ]
    },
     {
        "tag": "STB Firmware Update",
        "patterns": [
            "What should I do if the STB firmware is not updating on LAN after connecting it?"
        ],
        "responses": [
            "After connecting the STB over LAN, perform a factory reset of the STB and wait for 10 minutes. The firmware will automatically update."
        ]
    },

    {
        "tag": "STB Firmware Update",
        "patterns": ["STB firmware not updating on LAN", "STB firmware update issue on LAN", "LAN STB firmware not updating"],
        "responses": ["Connect STB over LAN, perform a factory reset, and wait for 10 minutes. Firmware will update automatically."]
    },
    {
        "tag": "STB Firmware Update",
        "patterns": ["STB firmware not updating on Wi-Fi", "Wi-Fi STB firmware update issue", "STB firmware not updating via Wi-Fi"],
        "responses": ["Change DNS settings in ONT: Log in to ONT, select Network, then WAN, IPV4 Configuration. Choose 'Use these DNS Servers', input primary DNS as 8.8.8.8 and secondary DNS as 8.8.4.4. Save and reboot."]
    },
    {
        "tag": "STB Connectivity with CRT TV",
        "patterns": ["CRT TV STB connectivity", "STB connection with CRT TV", "STB setup for CRT TV"],
        "responses": ["Customer needs a 3.5mm to 3 RCA male adaptor cable. Offer assistance in purchasing. If they prefer self-purchase, provide STB and advise to call for installation support. Update JPW remark accordingly."]
    },
    {
        "tag": "STB Validation Failure",
        "patterns": ["STB validation failure in JPW", "Manual entry of STB serial number", "STB scan unsuccessful in JPW"],
        "responses": ["If scan fails in JPW, enter STB serial number manually."]
    },
    {
        "tag": "Store Mismatch Error",
        "patterns": ["User and device store mismatch error", "Device used in different store", "Resolve store mismatch issue in POS"],
        "responses": ["Guide user to contact Device Store Person. In POS, go to utilities > Unregister devices > OK. Ask user to log in again. If issue persists, contact Partner IT Helpdesk at 18001033951."]
    },
    {
        "tag": "Voice Search Enabled Apps",
        "patterns": ["Apps with voice search option", "Voice search enabled applications", "Voice search in Jio apps"],
        "responses": ["Voice search enabled in YouTube, JIO Cinema, JIO Saavn, and Jio TV+."]
    },
    {
        "tag": "Customer Plan Top-Up",
        "patterns": ["Customer plan top-up after exhaustion", "Jiofiber plan exhaustion", "Top-up after plan exhaustion"],
        "responses": ["Customer can choose suitable Jiofiber plan from My Jio or jio.com based on their needs."]
    },
    {
        "tag": "Speed Test SOP",
        "patterns": ["Speed test procedure for 1GBPS", "1GBPS speed test steps", "Jiofiber speed test SOP"],
        "responses": ["Perform speed test using provided URL for respective locations. Follow process steps, disable firewalls and antivirus with customer consent, test on single LAN device. Enable Wi-Fi on ONT after testing."]
    },
    {
        "tag": "OTT App Subscription Issue",
        "patterns": ["Subscription issue in Sony Live or Hot Star", "OTT app asking for subscription in premium plans", "Premium content access problem"],
        "responses": ["Clear app data, force stop app. Wait 5-7 minutes, premium content will play. For further assistance, contact customer care."]
    },
    {
        "tag": "Redemption of Gifts",
        "patterns": ["Redemption of Bluetooth speakers or HD TV", "Customer gifts redemption process", "Redeem gifts from Reliance Digital or JIO Stores"],
        "responses": ["Redemption available from 31st Oct 19 at specific Reliance Digital or JIO Stores."]
    },
    {
        "tag": "Jiofiber Plan Speeds",
        "patterns": ["Upload and download speeds for Jiofiber plans", "Bronze plan speed details", "Platinum plan internet speed"],
        "responses": ["Bronze: 10 MBPS upload / 100 MBPS download, Silver: 10 MBPS upload / 100 MBPS download, Gold: 25 MBPS upload / 250 MBPS download, Diamond: 50 MBPS upload / 500 MBPS download, Platinum: 100 MBPS upload / 1 GBPS download, Titanium: 100 MBPS upload / 1 GBPS download."]
    },
    {
        "tag": "Mesh Installation Procedure",
        "patterns": ["Steps for Mesh installation", "Mesh device setup process", "Mesh network installation SOP"],
        "responses": ["Ensure JCO4032 device is available. Do not connect Mesh device before ONT firmware update. Connect Mesh Device to ONT via LAN, wait 10 minutes for update. Generate heat map on 5 GHz band only."]
    },
    {
        "tag": "Green Stable Browsing Issue",
        "patterns": ["Green Stable unable to browse", "Green Stable internet issue", "Troubleshoot Stable browsing problem"],
        "responses": ["Remove third-party switches and routers. Reboot ONT. Check if installation WO is in demo start state. Verify customer recharge status."]
    },
    {
        "tag": "ODCPE Power Light Blinking Issue",
        "patterns": ["Red Light blinking on ODCPE Power light", "ODCPE Power status problem", "Blinking Power light troubleshooting"],
        "responses": ["Check Power Level at S2 and ONT, should be <25dB. Power difference between S2 out and ONT should be <1-1.5 dBm. Ensure S2 serial number matches physically connected ONT. If O1, O2, or O3 status, check fiber connectivity. If O5, call THD for replacement."]
    },
    {
        "tag": "OTT Apps Subscription Troubleshooting",
        "patterns": ["OTT apps asking for subscription", "Subscription issue in OTT applications", "Troubleshoot premium content access"],
        "responses": ["Clear data, caches, force stop apps. For Silver plan, if 4th recharge done, OTT apps will ask for subscription. Reset STB, reinstall apps. Premium content available for specific apps; others need personal login accounts."]
    },
    {
        "tag": "Speed Issue Troubleshooting",
        "patterns": ["Slow internet speed troubleshooting", "Jiofiber speed problem resolution", "Fix slow internet connection"],
        "responses": ["Check Power Level at S2 and ONT, should be <25dB. Power difference between S2 out and ONT should be <1-1.5 dBm. For speed below standards, contact THD. Test speed on single LAN device, remove third-party switches and routers. Follow specified laptop/device requirements. Use provided URL for speed test in Google Chrome only."]
    },
    {
        "tag": "DVR Configuration Issue",
        "patterns": ["DVR setup problem", "DVR not configuring with ONT", "Fix DVR configuration issue"],
        "responses": ["DVR should be directly connected to ONT, no external devices. Ensure customer has DVR port details; if not, advise them to obtain it from IT person."]
    },
    {
        "tag": "CAT6 Cable Connectivity Check",
        "patterns": ["Check CAT6 cable connectivity", "LAN Tester for CAT6 cable", "Verify CAT6 cable connection"],
        "responses": ["Use LAN Tester to check CAT6 cable connectivity."]
    },
    {
        "tag": "ODCPE Components",
        "patterns": ["Components in ODCPE box", "ODCPE box contents", "What's in ODCPE box?"],
        "responses": ["ODCPE box includes ODU unit, bracket, and POE (Power over Ethernet)."]
    },
    {
        "tag": "ODCPE Power Light Indication",
        "patterns": ["Meaning of blue blinking Power light on ODCPE", "Blue light on ODCPE Power indicator", "ODCPE blue light indication"],
        "responses": ["Blue blinking light indicates Ethernet is ON."]
    },
    {
        "tag": "CAT6 Cable Length",
        "patterns": ["Maximum length of CAT6 cable to avoid signal loss", "CAT6 cable signal loss limit", "CAT6 cable maximum length"],
        "responses": ["Maximum permissible length of CAT6 cable to avoid signal loss is 50 meters."]
    },
    {
        "tag": "RJ45 Crimping Color Code",
        "patterns": ["Color coding for RJ45 crimping", "RJ45 crimping color scheme", "RJ45 crimping colors"],
        "responses": ["RJ45 crimping color code: Orange + White - Orange, White + Green - Blue, White + Blue - Green, White + Brown - Brown."]
    },
    {
        "tag": "ODU Mount Location Check",
        "patterns": ["Checking ODU mount location", "ODU mount site inspection", "ODU mount location verification"],
        "responses": ["Ensure clear line of sight and verify direction using Net Velocity App when deciding ODU mount location."]
    },
    {
        "tag": "ICCID Digits in Syclo Process",
        "patterns": ["ICCID digits in Syclo process", "ICCID digits for Syclo", "Syclo ICCID input"],
        "responses": ["In Syclo process, insert 19 digits of ICCID."]
    },
    {
        "tag": "Customer Premise Exit Steps",
        "patterns": ["Steps before exiting customer premise", "Customer premise exit procedure", "Leaving customer location steps"],
        "responses": ["Conduct Speed Test demo, ensure successful My Jio Log in, provide customer care details before exiting customer premise."]
    },
    {
        "tag": "ORN Visibility Issue",
        "patterns": ["Troubleshoot ORN not visible in POS", "ORN visibility problem in POS", "Fix ORN visibility issue in POS"],
        "responses": ["If WO not processed in JPW, ORN won't appear in POS. It shows after JPW initiates Collect Payment process. Complete pre-payment tasks in JPW before POS."]
    },
    {
        "tag": "Payment Link Issues",
        "patterns": ["Payment link not opening on customer's mobile", "Payment confirmation not reflecting in JPW", "POS payment link problem"],
        "responses": ["Ensure customer's updated browser and good internet speed. Provide hotspot support if needed. Time-out may occur if browser left open for long."]
    },
    {
        "tag": "Payment Confirmation in JPW",
        "patterns": ["Payment confirmation not reflecting in JPW", "Payment link confirmation problem", "JPW payment update issue"],
        "responses": ["In POS, after sending payment link, click check-out, confirm payment via link, log in again to JPW for update."]
    },
    {
        "tag": "POS Errors and Resolutions",
        "patterns": ["Error in POS due to engineer mapped in adjacent JC", "Engineer mapped in wrong JC in POS", "POS payment initiation error"],
        "responses": ["In Burger menu, Utility, perform 'unregistered' action once. Then, collect money from mapped JC without issues."]
    },
    {
        "tag": "SA Camera Installation",
        "patterns": ["Purpose of installing SA Camera", "SA Camera function", "Why install SA Camera?"],
        "responses": ["SA Camera records activities at cash counter and entry points."]
    },
    {
        "tag": "HVA Full Form",
        "patterns": ["Full form of HVA", "Meaning of HVA", "What does HVA stand for?"],
        "responses": ["HVA stands for High Value Area."]
    },

    {
        "tag": "Home Automation Gateway IP Address",
        "patterns": ["IP Address of Home Automation Gateway", "Home Automation Gateway IoT Hub IP"],
        "responses": ["The IP Address of the Home Automation Gateway (IoT Hub) is 192.168.1.1."]
    },
    {
        "tag": "Home Gateway Model Name",
        "patterns": ["Model Name of Home Gateway", "Home Gateway identifier"],
        "responses": ["The Model Name of the Home Gateway is JCE100."]
    },
    {
        "tag": "Mobile Application for NVR and Cameras",
        "patterns": ["Mobile app to activate NVR and Cameras", "App for NVR and Cameras setup"],
        "responses": ["The mobile application used to activate NVR and Cameras is 'Ivms 4500'."]
    },
    {
        "tag": "Motion Sensor Installation Height",
        "patterns": ["Height for Motion Sensor installation", "Motion Sensor mounting level"],
        "responses": ["Motion Sensor should be installed at a height of 2300 mm from the ground level."]
    },
    {
        "tag": "NVR Full Form",
        "patterns": ["Full form of NVR", "NVR acronym meaning"],
        "responses": ["NVR stands for Network Video Recorder."]
    },
    {
        "tag": "Camera Power Voltage",
        "patterns": ["Power Voltage of camera", "Camera electrical voltage"],
        "responses": ["The power voltage of the camera is 12 volts."]
    },
    {
        "tag": "SMPS Outputs",
        "patterns": ["Number of outputs in SMPS", "SMPS output connections"],
        "responses": ["SMPS has 4 outputs."]
    },
    {
        "tag": "Siren Installation Location",
        "patterns": ["Location for Siren installation", "Siren mounting position"],
        "responses": ["Siren should be installed between the shutter and glass door."]
    },
    {
        "tag": "Pre-Visit Procedure to JioPoint Store",
        "patterns": ["Engineer pre-visit tasks at JioPoint store", "JioPoint store visit preparation"],
        "responses": ["Before visiting a JioPoint store, the engineer will conduct a video call with the JioPoint Manager (JPM) or JioPoint Assistant Manager (JPAM) to confirm store readiness."]
    },
    {
        "tag": "HOTO/Installation Report Authorization",
        "patterns": ["HOTO/Installation report sign-off authority", "Authorized person for HOTO report"],
        "responses": ["The HOTO/Installation report will be signed off and stamped by the store team, either the JioPoint Manager (JPM) or JioPoint Assistant Manager (JPAM)."]
    },
    {
        "tag": "JioPoint Store Opening Procedure",
        "patterns": ["JPM/JPAM tasks to open JioPoint Store", "JioPoint Store opening steps"],
        "responses": ["Every morning, the JioPoint Manager (JPM) or JioPoint Assistant Manager (JPAM) will perform JioHome disarming to open the JioPoint Store."]
    },
    {
        "tag": "Devices Scanned in JPW",
        "patterns": ["Devices scanned in JPW", "JPW scanning devices"],
        "responses": ["The engineer will scan the ODCPE, IoT, Home gateway, and SIM in JPW."]
    },



              {"tag": "greeting",
              "patterns": [ "Hi", "Hello", "Hey"],
              "responses": ["Hi there", "Hello", "Hi :)"],
             },
              {"tag": "goodbye",
              "patterns": [ "bye", "later"],
              "responses": ["Bye", "take care"]
             },
             {"tag": "name",
              "patterns": ["what's your name?", "who are you?"],
              "responses": ["I have no name yet," "You can give me one, and I will appreciate it"]
             }

]}

# %%
lm = WordNetLemmatizer() #for getting words
# lists
ourClasses = []
newWords = []
documentX = []
documentY = []
# Each intent is tokenized into words and the patterns and their associated tags are added to their respective lists.
for intent in ourData["ourIntents"]:
    for pattern in intent["patterns"]:
        ournewTkns = nltk.word_tokenize(pattern)# tokenize the patterns
        newWords.extend(ournewTkns)# extends the tokens
        documentX.append(pattern)
        documentY.append(intent["tag"])


    if intent["tag"] not in ourClasses:# add unexisting tags to their respective classes
        ourClasses.append(intent["tag"])

newWords = [lm.lemmatize(word.lower()) for word in newWords if word not in string.punctuation] # set words to lowercase if not in punctuation
newWords = sorted(set(newWords))# sorting words
ourClasses = sorted(set(ourClasses))# sorting classes

# %%
print(newWords)
# Out:
# ["'s", 'are', 'bye', 'hello', 'hey', 'hi', 'how', 'later', 'name', 'old', 'what', 'who', 'you', 'your']

# %%
print(ourClasses)
# Out:
# ['age', 'goodbye', 'greeting', 'name']

# %%
trainingData = [] # training list array
outEmpty = [0] * len(ourClasses)
# BOW model
for idx, doc in enumerate(documentX):
    bagOfwords = []
    text = lm.lemmatize(doc.lower())
    for word in newWords:
        bagOfwords.append(1) if word in text else bagOfwords.append(0)

    outputRow = list(outEmpty)
    outputRow[ourClasses.index(documentY[idx])] = 1
    trainingData.append([bagOfwords, outputRow])

random.shuffle(trainingData)
trainingData = num.array(trainingData, dtype=object)# coverting our data into an array afterv shuffling

x = num.array(list(trainingData[:, 0]))# first trainig phase
y = num.array(list(trainingData[:, 1]))# second training phase

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
import tensorflow as tf

iShape = (len(x[0]),)
oShape = len(y[0])

# parameter definition
ourNewModel = Sequential()

# Dense function adds an output layer
ourNewModel.add(Dense(128, input_shape=iShape, activation="relu"))
ourNewModel.add(Dropout(0.5))
ourNewModel.add(Dense(64, activation="relu"))
ourNewModel.add(Dropout(0.3))
ourNewModel.add(Dense(oShape, activation="softmax"))

# Use legacy optimizer
md = tf.keras.optimizers.legacy.Adam(learning_rate=0.01, decay=1e-6)

# Compile the model
ourNewModel.compile(loss='categorical_crossentropy', optimizer=md, metrics=["accuracy"])

# Output the model summary
print(ourNewModel.summary())

# Train the model
ourNewModel.fit(x, y, epochs=200, verbose=1)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense (Dense)               (None, 128)               33024
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 64)                8256
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  dense_2 (Dense)             (None, 46)                2990
#
# ...
# Total params: 44270 (172.93 KB)
# Trainable params: 44270 (172.93 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# Epoch 1/200
# 5/5 [==============================] - 1s 8ms/step - loss: 3.8356 - accuracy: 0.0379
# Epoch 2/200
# 5/5 [==============================] - 0s 4ms/step - loss: 3.5371 - accuracy: 0.1364
# Epoch 3/200
# 5/5 [==============================] - 0s 4ms/step - loss: 3.1216 - accuracy: 0.2045
# Epoch 4/200
# ...

# %%
def ourText(text):
  newtkns = nltk.word_tokenize(text)
  newtkns = [lm.lemmatize(word) for word in newtkns]
  return newtkns

def wordBag(text, vocab):
  newtkns = ourText(text)
  bagOwords = [0] * len(vocab)
  for w in newtkns:
    for idx, word in enumerate(vocab):
      if word == w:
        bagOwords[idx] = 1
  return num.array(bagOwords)

def pred_class(text, vocab, labels):
  bagOwords = wordBag(text, vocab)
  ourResult = ourNewModel.predict(num.array([bagOwords]))[0]
  newThresh = 0.2
  yp = [[idx, res] for idx, res in enumerate(ourResult) if res > newThresh]

  yp.sort(key=lambda x: x[1], reverse=True)
  newList = []
  for r in yp:
    newList.append(labels[r[0]])
  return newList

def getRes(firstlist, fJson):
  tag = firstlist[0]
  listOfIntents = fJson["ourIntents"]
  for i in listOfIntents:
    if i["tag"] == tag:
      ourResult = random.choice(i["responses"])
      break
  return ourResult

# %%
while True:
    newMessage = input("")
    intents = pred_class(newMessage, newWords, ourClasses)
    ourResult = getRes(intents, ourData)
    print(ourResult)
# Out:
# hey
# 1/1 [==============================] - 0s 87ms/step
# Hi :)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-548e35d82d70> in <cell line: 1>()
#       1 while True:
# ----> 2     newMessage = input("")
#       3     intents = pred_class(newMessage, newWords, ourClasses)
#       4     ourResult = getRes(intents, ourData)
#       5     print(ourResult)
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     849                 "raw_input was called, but this frontend does not support input requests."
#     850             )
# --> 851         return self._input_request(str(prompt),
#     852             self._parent_ident,
#     853             self._parent_header,
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
# ...

# %%
# Save the entire model to a file
chat.save('chat.h5')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-42b9ea14fdcc> in <cell line: 2>()
#       1 # Save the entire model to a file
# ----> 2 chat.save('chat.h5')
#
# NameError: name 'chat' is not defined
